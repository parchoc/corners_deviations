# %%
from plots import Plotter

# %%
plotter = Plotter()

# %%
plots = plotter.draw_plots('deviation.json')

# %%
plots
# Out:
# ['plots\\ceiling_floor_mean_scatter.png',
#  'plots\\corners_mean_bar.png',
#  'plots\\mean_hist.png']
